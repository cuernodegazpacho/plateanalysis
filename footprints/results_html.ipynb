# %% [markdown]
# # Results as HTML pages

# %% [markdown]
# This notebook runs in sequence the notebooks required to build the summary and analysis outputs for a given telescope. Outputs are in HTML format, and build on a per telescope basis.
#
# Inputs and outputs for this notebook are defined by parameter *tel_suffix* in file *settings.py*.

# %%
import os

import settings
from settings import RESULTS, tel_suffix

# %%
# output path
output_path_results = RESULTS

# %%
suffix = tel_suffix + ".html"

print("START", tel_suffix)

filename = os.path.join(output_path_results, "results_" + suffix)
# !jupyter nbconvert --to html --execute results.ipynb --output $filename

filename = os.path.join(output_path_results, "results_analysis_" + suffix)
# !jupyter nbconvert --to html --execute results_analysis.ipynb --output $filename

print("END")
# Out:
# START DR
# [NbConvertApp] Converting notebook results.ipynb to html
# [NbConvertApp] Writing 339136 bytes to results/results_DR.html
# [NbConvertApp] Converting notebook results_analysis.ipynb to html
# [NbConvertApp] Writing 537930 bytes to results/results_analysis_DR.html
# END
